# %% [markdown]
# # Latent Dirichlet Allocation (LDA)

# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.7.3)

# %% [markdown]
# This Colab is taken and modified from [here](https://colab.research.google.com/github/dudaspm/LDA_Bias_Data/blob/main/Latent%20Dirichlet%20Allocation%20(LDA).ipynb)
#
# <center>
# <img src="https://www.gutenberg.org/files/55/55-h/images/cover.jpg"  width="300"></img>
# </center>
#
# The Wonderful Wizard of Oz via https://www.gutenberg.org/ebooks/55

# %% [markdown]
# * What are topics?
#     * The topics will X number of sets of terms (we define this X) which will (could) have a common theme.
# * How are they defined?
#     * This is what we will get to in this notebook.
# * Do we define or does the computer?
#     * LDA is unsupervised, so we define the number of topics. The computer provides the topics themselves.
# * What is a large corpus? and How many documents do we need?
#     * A bit subjective here. There is a *great* discussion about this by Tang et al.  {cite:p}`tang2014understanding` regarding this. If you have a chance, read all the points, but to sum it up
#         * The number of documents does matter, but at some point, increasing the number does not warrant better results. Even sampling 1000 papers from 1000000 papers could result in the same, if not better, results than 1000000 documents.
#         * The size of the documents also plays a role, so documents should not be short. Larger documents can be sampled and again receive the same desired output.

# %% [markdown]
# For more information about LDA, please review [this high level article](https://www.cs.columbia.edu/~blei/papers/Blei2012.pdf). If interested, review at my office hours, and consider taking CS6120: Natural Language Processing. In this course, we will be applying LDA with some base understandings of the approach.
#
# <center>
# <img src="http://deliveryimages.acm.org/10.1145/2140000/2133826/figs/f1.jpg"  width="600"></img>
# </center>
# Figure 1. The intuitions behind latent Dirichlet allocation. We assume that some number of "topics," which are distributions over words, exist for the whole collection (far left). Each document is assumed to be generated as follows. First choose a distribution over the topics (the histogram at right); then, for each word, choose a topic assignment (the colored coins) and choose the word from the corresponding topic. The topics and topic assignments in this figure are illustrative—they are not fit from real data. (Page 3)
#
#
# <center>
# <img src="https://deliveryimages.acm.org/10.1145/2140000/2133826/figs/f2.jpg"  width="600"></img>
# </center>
# Figure 2. Real inference with LDA. We fit a 100-topic LDA model to 17,000 articles from the journal Science. At left are the inferred topic proportions for the example article in Figure 1. At right are the top 15 most frequent words from the most frequent topics found in this article.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%capture
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sklearn in /usr/local/lib/python3.8/dist-packages (0.0.post1)

# %% [markdown]
# ## Let's Try an Example

# %%
# urlopen -> html format
from urllib.request import urlopen
from bs4 import BeautifulSoup

# download many books from the websites

# The Wonderful Wizard of Oz
url = "https://www.gutenberg.org/files/55/55-h/55-h.htm" 
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
# Remove CSS (style) or Javascript (script)
for script in soup(["script", "style"]):
    script.extract()
# Read the text
text = soup.get_text()
# create the inital list
documents = []
documents.append(text)

# The Marvellous Land of Oz
url = "https://www.gutenberg.org/files/54/54-h/54-h.htm" 
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

# Ozma of Oz
url = "https://www.gutenberg.org/files/33361/33361-h/33361-h.htm" 
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

# Dorothy and the Wizard of Oz
url = "https://www.gutenberg.org/files/22566/22566-h/22566-h.htm" 
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

# The Road to Oz
url = "https://www.gutenberg.org/files/26624/26624-h/26624-h.htm" 
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

# Earliest Years at Vassar
url = "https://www.gutenberg.org/cache/epub/46080/pg46080-images.html" 
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

# Days in Queensland
url = "https://www.gutenberg.org/cache/epub/38649/pg38649-images.html" 
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")
for script in soup(["script", "style"]):
    script.extract()
text = soup.get_text()
documents.append(text)

# %% [markdown]
# ### Create Tokens and Vocabulary
#
# Now that we have our books, we need to tokenize the stories by word and then create a vocabulary out of these tokens. Note that we eliminate extremely common words that do not contribute much to the meaning of a document and topic (like `the`, `and`, `or`, etc.). These are called *stop words*.

# %%
from sklearn.feature_extraction.text import CountVectorizer


cv = CountVectorizer(stop_words='english')
df = cv.fit_transform(documents)
vocab = cv.get_feature_names()
print(vocab)
cv1 = CountVectorizer(stop_words='Beer')
df1 = cv.fit_transform(documents)
vocab1 = cv.get_feature_names()
print(vocab1)


print(df[0])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00', '000', '010', '058', '083', '10', '100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '10d', '10s', '10th', '10the', '11', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '11th', '11they', '12', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '12a', '12th', '13', '130', '131', '132', '133', '134', '135', '136', '137', '137th', '138', '139', '13th', '13the', '14', '140', '141', '142', '143', '144', '145', '146', '147', '148', '1485', '1486', '149', '14ozma', '15', '150', '1500', '151', '152', '153', '154', '155', '156', '157', '158', '159', '15old', '15s', '15th', '16', '160', '1605', '1606', '161', '162', '163', '164', '165', '166', '167', '168', '1688', '169', '16jim', '16th', '17', '170', '171', '172', '173', '174', '175', '176', '1769', '177', '1770', '178', '1781', '179', '1791', '1798', '1799', '17th', '17the', '18', '180', '1801', '1802', '1803', '181', '1816', '182', '1823', '1824', '1825', '1827', '1828', '183', '1838', '1839', '184', '1840', '1841', '1842', '1843', '1844', '1845', '1846', '1847', '1848', '185', '1850', '1851', '1853', '1854', '1855', '1856', '1857', '1858', '1859', '186', '1860', '1861', '1862', '1863', '1864', '1865', '1866', '1867', '1868', '1869', '187', '1870', '1871', '1872', '1873', '1874', '1875', '1876', '1878', '1879', '188', '1880', '1881', '1882', '1883', '1884', '1885', '1886', '1887', '1888', '189', '1891', '1892', '1893', '1894', '1895', '1896', '1897', '1898', '1899', '18th', '18the', '19', '190', '1900', '1901', '1902', '1903', '1904', '1907', '1908', '1909', '191', '192', '193', '194', '195', '196', '197', '198', '199', '1993', '19th', '19the', '1a', '1d', '1s', '1st', '1the', '20', '200', '2001', '2007', '2008', '201', '2010', '2012', '2014', '202', '2020', '2022', '203', '204', '205', '206', '207', '208', '209', '20s', '20th', '20zeb', '21', '210', '211', '212', '213', '214', '215', '216', '217', '218', '219', '21s', '21st', '22', '220', '221', '222', '223', '224', '225', '22566', '226', '227', '228', '229', '22nd', '23', '230', '231', '232', '233', '234', '235', '236', '237', '238', '239', '23rd', '24', '240', '241', '242', '243', '244', '245', '246', '247', '248', '249', '24th', '25', '250', '251', '252', '253', '254', '255', '256', '257', '258', '259', '25th', '26', '260', '261', '262', '263', '264', '265', '266', '26624', '267', '268', '269', '26th', '27', '270', '27th', '28', '28th', '29', '29th', '2d', '2nd', '2s', '2the', '30', '300', '30s', '30th', '31', '31st', '32', '320', '322', '33', '33361', '339', '34', '35', '353', '35s', '36', '362', '369', '37', '370', '38', '381', '382', '384', '386', '38649', '38s', '39', '3d', '3rd', '3s', '3the', '40', '400', '40s', '41', '411', '415', '418', '42', '43', '430', '435', '44', '45', '450', '4557', '458', '45s', '45th', '46', '46080', '47', '48', '481', '49', '4d', '4s', '4th', '4the', '4to', '50', '500', '501', '51', '515', '518', '52', '53', '54', '55', '55117', '552', '56', '57', '578', '579', '58', '59', '596', '5d', '5dorothy', '5s', '5th', '60', '600', '61', '62', '6221541', '63', '64', '643', '65', '650', '66', '67', '68', '69', '690', '6a', '6d', '6s', '6th', '6the', '70', '71', '718', '72', '720', '73', '735', '74', '75', '76', '77', '78', '79', '793', '7d', '7into', '7s', '7th', '80', '800', '801', '809', '81', '82', '83', '84', '84116', '85', '86', '87', '88', '8859', '89', '8d', '8s', '8th', '8the', '8vo', '90', '91', '92', '93', '94', '95', '950', '96', '97', '98', '983', '99', '99712', '998', '9d', '9s', '9th', '9they', 'ab', 'abandon', 'abandoned', 'abashed', 'abbreviated', 'abbreviation', 'abbreviations', 'abby', 'abeyance', 'abide', 'abided', 'abides', 'ability', 'abject', 'able', 'ably', 'aboard', 'abolished', 'aboriginal', 'aboriginals', 'aborigine', 'aborigines', 'abound', 'abounded', 'abounding', 'abraded', 'abrasion', 'abridgment', 'abroad', 'abrupt', 'abruptly', 'absence', 'absent', 'absentees', 'absolute', 'absolutely', 'absorb', 'absorbed', ...
# ['00', '000', '010', '058', '083', '10', '100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '10d', '10s', '10th', '10the', '11', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '11th', '11they', '12', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '12a', '12th', '13', '130', '131', '132', '133', '134', '135', '136', '137', '137th', '138', '139', '13th', '13the', '14', '140', '141', '142', '143', '144', '145', '146', '147', '148', '1485', '1486', '149', '14ozma', '15', '150', '1500', '151', '152', '153', '154', '155', '156', '157', '158', '159', '15old', '15s', '15th', '16', '160', '1605', '1606', '161', '162', '163', '164', '165', '166', '167', '168', '1688', '169', '16jim', '16th', '17', '170', '171', '172', '173', '174', '175', '176', '1769', '177', '1770', '178', '1781', '179', '1791', '1798', '1799', '17th', '17the', '18', '180', '1801', '1802', '1803', '181', '1816', '182', '1823', '1824', '1825', '1827', '1828', '183', '1838', '1839', '184', '1840', '1841', '1842', '1843', '1844', '1845', '1846', '1847', '1848', '185', '1850', '1851', '1853', '1854', '1855', '1856', '1857', '1858', '1859', '186', '1860', '1861', '1862', '1863', '1864', '1865', '1866', '1867', '1868', '1869', '187', '1870', '1871', '1872', '1873', '1874', '1875', '1876', '1878', '1879', '188', '1880', '1881', '1882', '1883', '1884', '1885', '1886', '1887', '1888', '189', '1891', '1892', '1893', '1894', '1895', '1896', '1897', '1898', '1899', '18th', '18the', '19', '190', '1900', '1901', '1902', '1903', '1904', '1907', '1908', '1909', '191', '192', '193', '194', '195', '196', '197', '198', '199', '1993', '19th', '19the', '1a', '1d', '1s', '1st', '1the', '20', '200', '2001', '2007', '2008', '201', '2010', '2012', '2014', '202', '2020', '2022', '203', '204', '205', '206', '207', '208', '209', '20s', '20th', '20zeb', '21', '210', '211', '212', '213', '214', '215', '216', '217', '218', '219', '21s', '21st', '22', '220', '221', '222', '223', '224', '225', '22566', '226', '227', '228', '229', '22nd', '23', '230', '231', '232', '233', '234', '235', '236', '237', '238', '239', '23rd', '24', '240', '241', '242', '243', '244', '245', '246', '247', '248', '249', '24th', '25', '250', '251', '252', '253', '254', '255', '256', '257', '258', '259', '25th', '26', '260', '261', '262', '263', '264', '265', '266', '26624', '267', '268', '269', '26th', '27', '270', '27th', '28', '28th', '29', '29th', '2d', '2nd', '2s', '2the', '30', '300', '30s', '30th', '31', '31st', '32', '320', '322', '33', '33361', '339', '34', '35', '353', '35s', '36', '362', '369', '37', '370', '38', '381', '382', '384', '386', '38649', '38s', '39', '3d', '3rd', '3s', '3the', '40', '400', '40s', '41', '411', '415', '418', '42', '43', '430', '435', '44', '45', '450', '4557', '458', '45s', '45th', '46', '46080', '47', '48', '481', '49', '4d', '4s', '4th', '4the', '4to', '50', '500', '501', '51', '515', '518', '52', '53', '54', '55', '55117', '552', '56', '57', '578', '579', '58', '59', '596', '5d', '5dorothy', '5s', '5th', '60', '600', '61', '62', '6221541', '63', '64', '643', '65', '650', '66', '67', '68', '69', '690', '6a', '6d', '6s', '6th', '6the', '70', '71', '718', '72', '720', '73', '735', '74', '75', '76', '77', '78', '79', '793', '7d', '7into', '7s', '7th', '80', '800', '801', '809', '81', '82', '83', '84', '84116', '85', '86', '87', '88', '8859', '89', '8d', '8s', '8th', '8the', '8vo', '90', '91', '92', '93', '94', '95', '950', '96', '97', '98', '983', '99', '99712', '998', '9d', '9s', '9th', '9they', 'ab', 'abandon', 'abandoned', 'abashed', 'abbreviated', 'abbreviation', 'abbreviations', 'abby', 'abeyance', 'abide', 'abided', 'abides', 'ability', 'abject', 'able', 'ably', 'aboard', 'abolished', 'aboriginal', 'aboriginals', 'aborigine', 'aborigines', 'abound', 'abounded', 'abounding', 'abraded', 'abrasion', 'abridgment', 'abroad', 'abrupt', 'abruptly', 'absence', 'absent', 'absentees', 'absolute', 'absolutely', 'absorb', 'absorbed', ...
#   (0, 9720)	89
#   (0, 5998)	99
#   (0, 4342)	14
#   (0, 13956)	28
#   (0, 13933)	44
#   (0, 8868)	169
#   (0, 5434)	5
#   (0, 1431)	5
#   (0, 13349)	28
#   (0, 13234)	15
#   (0, 11900)	19
#   (0, 8980)	2
#   (0, 13999)	19
#   (0, 3170)	4
#   (0, 10458)	2
#   (0, 13772)	2
#   (0, 3122)	12
#   (0, 1278)	71
#   (0, 12552)	22
#   (0, 7428)	18
#   (0, 6639)	3
#   (0, 8693)	4
#   (0, 14057)	10
#   (0, 8741)	10
#   (0, 7540)	7
#   :	:
#   (0, 8888)	1
#   (0, 4095)	1
#   (0, 8013)	1
#   (0, 639)	1
#   (0, 13690)	1
#   (0, 3279)	1
#   (0, 2231)	1
#   (0, 9701)	1
#   (0, 8018)	1
#   (0, 6119)	1
#   (0, 8758)	1
#   (0, 11172)	1
#   (0, 9691)	1
#   (0, 7584)	1
#   (0, 8443)	1
#   (0, 13543)	1
#   (0, 2938)	1
#   (0, 8397)	1
#   (0, 4360)	1
#   (0, 7711)	1
#   (0, 9201)	1
#   (0, 4918)	1
#   (0, 9690)	1
#   (0, 12159)	1
#   (0, 8454)	1

# %%
print(df[1])
# Out:
#   (0, 9720)	89
#   (0, 5998)	98
#   (0, 4342)	14
#   (0, 13956)	20
#   (0, 13933)	39
#   (0, 8868)	42
#   (0, 5434)	9
#   (0, 1431)	5
#   (0, 13349)	42
#   (0, 13234)	15
#   (0, 11900)	19
#   (0, 8980)	4
#   (0, 13999)	16
#   (0, 3170)	4
#   (0, 10458)	2
#   (0, 13772)	2
#   (0, 3122)	13
#   (0, 1278)	41
#   (0, 12552)	23
#   (0, 7428)	18
#   (0, 6639)	3
#   (0, 8693)	4
#   (0, 14057)	9
#   (0, 8741)	9
#   (0, 7540)	8
#   :	:
#   (0, 9164)	1
#   (0, 5860)	1
#   (0, 10519)	1
#   (0, 2948)	1
#   (0, 9179)	1
#   (0, 11106)	1
#   (0, 3998)	1
#   (0, 954)	1
#   (0, 13306)	1
#   (0, 10130)	1
#   (0, 8961)	1
#   (0, 2664)	1
#   (0, 5461)	1
#   (0, 1279)	1
#   (0, 4721)	1
#   (0, 13811)	1
#   (0, 10933)	1
#   (0, 12121)	1
#   (0, 4365)	1
#   (0, 501)	1
#   (0, 533)	1
#   (0, 6839)	1
#   (0, 2915)	1
#   (0, 707)	1
#   (0, 12927)	2

# %%
df
# Out:
# <7x14142 sparse matrix of type '<class 'numpy.int64'>'
# 	with 32436 stored elements in Compressed Sparse Row format>

# %%
# print df 0 as display purpose
df[0].max()
# Out:
# 369

# %% [markdown]
# Let's take a look at the tokens and the number of occurrence for the tokens.
#
# Question: What do the dimensions in df mean?

# %%
# PLAY AROUND WITH `df` HERE

# %% [markdown]
# In the variable `df`, the second number listed is the token number, and we use the vocab list to see what the actual word. An example would be to look at the first line.
#
# ```python
# (0, 8074) 3198
# ```
# The 8074 token was used 3198 times. The 8074 token is:
#
# Question: What word/vocab does token 8074 correspond to? How many times is it used? Is this surprising?

# %%
# YOUR CODE HERE
vocab[8074]
# Out:
# 'mins'

# %% [markdown]
# From here, we are actually at the point where we can run LDA.
#
# There are much more than two inputs available for LDA, but we will focus on two.
# > Here are the other inputs: https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html
#
# The two we will focus on are:
#
# * n_components - the number of topics, again, we need to specify this
# * doc_topic_prior - this relates the Dirichlet distribution (the next notebook goes into full detail about Dirichlet and how it relates to LDA.

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components = 100, doc_topic_prior=1)

# YOUR CODE HERE
lda.fit(df)
# Out:
# LatentDirichletAllocation(doc_topic_prior=1, n_components=100)

# %% [markdown]
# To print out the top-5 words per topic, we used a solution from StackOverflow.

# %%
import numpy as np 
topic_words = {}
n_top_words = 10

try:
  for topic, comp in enumerate(lda.components_):
      # for the n-dimensional array "arr":
      # argsort() returns a ranked n-dimensional array of arr, call it "ranked_array"
      # which contains the indices that would sort arr in a descending fashion
      # for the ith element in ranked_array, ranked_array[i] represents the index of the
      # element in arr that should be at the ith index in ranked_array
      # ex. arr = [3,7,1,0,3,6]
      # np.argsort(arr) -> [3, 2, 0, 4, 5, 1]
      # word_idx contains the indices in "topic" of the top num_top_words most relevant
      # to a given topic ... it is sorted ascending to begin with and then reversed (desc. now)    
      word_idx = np.argsort(comp)[::-1][:n_top_words]

      # store the words most relevant to the topic
      topic_words[topic] = [vocab[i] for i in word_idx]
      
  for topic, words in topic_words.items():
      print('Topic: %d' % topic)
      print('  %s' % ', '.join(words))
except:
  print("Did you fit the data?")
# Out:
# Topic: 0
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 1
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 2
#   river, country, mr, queensland, new, north, stock, gulf, water, great
# Topic: 3
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 4
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 5
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 6
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 7
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 8
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 9
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 10
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 11
#   pg, horse, great, little, way, country, project, land, time, followed
# Topic: 12
#   miss, college, gutenberg, project, day, vassar, lyman, work, professor, students
# Topic: 13
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 14
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 15
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 16
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 17
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 18
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 19
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 20
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 21
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 22
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 23
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 24
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 25
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 26
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 27
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 28
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 29
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 30
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 31
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 32
#   74, philalethean, candidate, 75, somebody, amusing, smith, petty, progressive, alida
# Topic: 33
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 34
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 35
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 36
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 37
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 38
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 39
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 40
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 41
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 42
#   halloran, francis, volumes, creditable, mack, revives, twine, values, negotiations, welford
# Topic: 43
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 44
#   dorothy, said, king, pg, billina, ozma, hen, nome, girl, scarecrow
# Topic: 45
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 46
#   market, pastoralists, ninety, geologist, tate, cambridge, sandstones, adding, principle, academy
# Topic: 47
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 48
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 49
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 50
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 51
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 52
#   frisk, unhitch, zygomaturus, evade, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 53
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 54
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 55
#   inquiry, dingo, strezlecki, warrineyahgooburry, kanakas, duplicate, prolific, recognises, sites, everal
# Topic: 56
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 57
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 58
#   said, tip, scarecrow, horse, jack, saw, woodman, tin, pumpkinhead, mombi
# Topic: 59
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 60
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 61
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 62
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 63
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 64
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 65
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 66
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 67
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 68
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 69
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 70
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 71
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 72
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 73
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 74
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 75
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 76
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 77
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 78
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 79
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 80
#   dorothy, said, man, little, asked, oz, wizard, gutenberg, good, project
# Topic: 81
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 82
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 83
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 84
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 85
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 86
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 87
#   occasions, association, adopted, succession, holds, attainments, stainburne, outlying, drawbacks, poisoning
# Topic: 88
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 89
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 90
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 91
#   mitchell, evening, gutenberg, project, college, years, work, students, teachers, student
# Topic: 92
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 93
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 94
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 95
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 96
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 97
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 98
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
# Topic: 99
#   zygomaturus, eventually, evesham, eves, everybody, eversleigh, evermore, everlasting, evergreens, evergreen
